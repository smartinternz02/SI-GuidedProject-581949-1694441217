# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.shape
# Out:
# (344, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# Visualization

# %%
#univariate Analysis
sns.distplot(df.culmen_length_mm)
# Out:
# <ipython-input-5-fb11cc170b4f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.displot(df.culmen_depth_mm)

# %%
plt.pie(df.sex.value_counts(),[0,0.1],labels = ['MALE','FEMALE'],autopct ='%1.1f%%',shadow = True,colors = ['black','yellow'])
plt.title('SEX')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4c6edf315347> in <cell line: 1>()
# ----> 1 plt.pie(df.sex.value_counts(),[0,0.1],labels = ['MALE','FEMALE'],autopct ='%1.1f%%',shadow = True,colors = ['black','yellow'])
#       2 plt.title('SEX')
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
sns.barplot(x =df.sex.value_counts().index,y =df.sex.value_counts() )
# Out:
# <Axes: ylabel='sex'>

# %%
#Bivariate Analysis
sns.lineplot(x = df.sex,y=df.body_mass_g)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
sns.lineplot(x = df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.scatterplot(x = df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
#Multivariate Analysis
sns.pairplot(df)

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.culmen_length_mm.median()
# Out:
# 44.45

# %%
df.culmen_length_mm.mean()
# Out:
# 43.9219298245614

# %%
df.culmen_length_mm = df.culmen_length_mm.fillna(df.culmen_length_mm.median())

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45              NaN                NaN
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.culmen_depth_mm.median()
# Out:
# 17.3

# %%
df.culmen_depth_mm.mean()
# Out:
# 17.151169590643278

# %%
df.culmen_depth_mm = df.culmen_depth_mm.fillna(df.culmen_depth_mm.median())

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3                NaN
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.flipper_length_mm.median()
# Out:
# 197.0

# %%
df.flipper_length_mm.mean()
# Out:
# 200.91520467836258

# %%
df.flipper_length_mm = df.flipper_length_mm.fillna(df.flipper_length_mm.median())

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.	body_mass_g.median()
# Out:
# 4050.0

# %%
df.	body_mass_g.mean()
# Out:
# 4201.754385964912

# %%
df.body_mass_g = df.body_mass_g.fillna(df.body_mass_g.median())

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0     NaN
# 4       3450.0  FEMALE

# %%
df.sex.mode()
# Out:
# 0    MALE
# Name: sex, dtype: object

# %%
df.sex = df.sex.fillna(df.sex.mode())

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# Outlier detection

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0     NaN
# 4       3450.0  FEMALE

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# <ipython-input-55-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235000           0.655858
# culmen_depth_mm           -0.235000         1.000000          -0.583832
# flipper_length_mm          0.655858        -0.583832           1.000000
# body_mass_g                0.594925        -0.471942           0.871221
#
#                    body_mass_g
# culmen_length_mm      0.594925
# culmen_depth_mm      -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-56-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# 1.Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.culmen_length_mm = le.fit_transform(df.culmen_length_mm)
df.culmen_depth_mm = le.fit_transform(df.culmen_depth_mm)

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen                42               56              181.0
# 1  Adelie  Torgersen                45               43              186.0
# 2  Adelie  Torgersen                51               49              195.0
# 3  Adelie  Torgersen                85               42              197.0
# 4  Adelie  Torgersen                22               62              193.0
#
#    body_mass_g  sex
# 0       3750.0   42
# 1       3800.0   45
# 2       3250.0   51
# 3       4050.0   85
# 4       3450.0   22

# %% [markdown]
# 2.One-hot Encoding Method

# %%
df_main = pd.get_dummies(df,columns =['island'])
df_main.head()
# Out:
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie                42               56              181.0       3750.0
# 1  Adelie                45               43              186.0       3800.0
# 2  Adelie                51               49              195.0       3250.0
# 3  Adelie                85               42              197.0       4050.0
# 4  Adelie                22               62              193.0       3450.0
#
#    sex  island_Biscoe  island_Dream  island_Torgersen
# 0   42              0             0                 1
# 1   45              0             0                 1
# 2   51              0             0                 1
# 3   85              0             0                 1
# 4   22              0             0                 1

# %%
df_main.corr()
# Out:
# <ipython-input-67-b764c75a6398>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_main.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.239792           0.659542
# culmen_depth_mm           -0.239792         1.000000          -0.586606
# flipper_length_mm          0.659542        -0.586606           1.000000
# body_mass_g                0.594217        -0.475381           0.871221
# sex                        1.000000        -0.239792           0.659542
# island_Biscoe              0.236738        -0.632573           0.609679
# island_Dream               0.037928         0.459118          -0.419241
# island_Torgersen          -0.381196         0.267338          -0.288840
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_main.corr(),annot =True)
# Out:
# <ipython-input-68-141015bc01e3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_main.corr(),annot =True)
# <Axes: >

# %%
df_main.corr().flipper_length_mm.sort_values(ascending=False)
# Out:
# <ipython-input-76-e8cfae49d8e4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_main.corr().flipper_length_mm.sort_values(ascending=False)
# flipper_length_mm    1.000000
# body_mass_g          0.871221
# culmen_length_mm     0.659542
# sex                  0.659542
# island_Biscoe        0.609679
# island_Torgersen    -0.288840
# island_Dream        -0.419241
# culmen_depth_mm     -0.586606
# Name: flipper_length_mm, dtype: float64

# %%
df_main.head()
# Out:
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie                42               56              181.0       3750.0
# 1  Adelie                45               43              186.0       3800.0
# 2  Adelie                51               49              195.0       3250.0
# 3  Adelie                85               42              197.0       4050.0
# 4  Adelie                22               62              193.0       3450.0
#
#    sex  island_Biscoe  island_Dream  island_Torgersen
# 0   42              0             0                 1
# 1   45              0             0                 1
# 2   51              0             0                 1
# 3   85              0             0                 1
# 4   22              0             0                 1

# %% [markdown]
# X and y split, independent variable and dependent varaible

# %%
y = df_main['flipper_length_mm']
y
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 3      197.0
# 4      193.0
#        ...
# 339    197.0
# 340    215.0
# 341    222.0
# 342    212.0
# 343    213.0
# Name: flipper_length_mm, Length: 344, dtype: float64

# %%
X =df_main.drop(columns =['culmen_length_mm'],axis =1)
X.head()
# Out:
#   species  culmen_depth_mm  flipper_length_mm  body_mass_g  sex  \
# 0  Adelie               56              181.0       3750.0   42
# 1  Adelie               43              186.0       3800.0   45
# 2  Adelie               49              195.0       3250.0   51
# 3  Adelie               42              197.0       4050.0   85
# 4  Adelie               62              193.0       3450.0   22
#
#    island_Biscoe  island_Dream  island_Torgersen
# 0              0             0                 1
# 1              0             0                 1
# 2              0             0                 1
# 3              0             0                 1
# 4              0             0                 1

# %% [markdown]
# Scaling on independent variables

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=10)

# %%
X_train.shape

# %%
X_train.shape

# %%
y_train.shape

# %%
X_test.shape
